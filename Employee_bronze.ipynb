# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
df_emp = spark.read.format('csv').option('header',True).load('/Volumes/workspace/default/test_practice/emp.csv')
df_emp.display()

# %%
df_emp.write.saveAsTable('emp_bronze')
